# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # PreProcessing

# %%
zomato_df = pd.read_csv(r"C:\Python_learning\Project_Data_Analysis\zomato.csv")
zomato_df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
zomato_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
zomato_df.describe(include= "all")
# Out:
#                                                       url        address  \
# count                                               51717          51717
# unique                                              51717          11495
# top     https://www.zomato.com/bangalore/jalsa-banasha...  Delivery Only
# freq                                                    1            128
# mean                                                  NaN            NaN
# std                                                   NaN            NaN
# min                                                   NaN            NaN
# 25%                                                   NaN            NaN
# 50%                                                   NaN            NaN
# 75%                                                   NaN            NaN
# max                                                   NaN            NaN
#
#                    name online_order book_table   rate         votes  \
# ...

# %%
Missing_Summary=pd.DataFrame({
    'Number Of Nulls':zomato_df.isna().sum(),
    'Nulls Precentage':round((zomato_df.isna().sum()/len(zomato_df))*100,2)
})
Missing_Summary
# Out:
#                              Number Of Nulls  Nulls Precentage
# url                                        0              0.00
# address                                    0              0.00
# name                                       0              0.00
# online_order                               0              0.00
# book_table                                 0              0.00
# rate                                    7775             15.03
# votes                                      0              0.00
# phone                                   1208              2.34
# location                                  21              0.04
# rest_type                                227              0.44
# dish_liked                             28078             54.29
# cuisines                                  45              0.09
# approx_cost(for two people)              346              0.67
# reviews_list                               0              0.00
# ...

# %%
zomato_df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %% [markdown]
# # Rate Column

# %%
zomato_df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', nan, '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
zomato_df[zomato_df['rate'].isna()==True]
# Out:
#                                                      url  \
# 84     https://www.zomato.com/bangalore/chill-out-ban...
# 90     https://www.zomato.com/bangalore/me-and-my-cak...
# 91     https://www.zomato.com/bangalore/sunsadm-banas...
# 92     https://www.zomato.com/bangalore/annapooranesh...
# 107    https://www.zomato.com/bangalore/coffee-shopee...
# ...                                                  ...
# 51644  https://www.zomato.com/bangalore/punjabi-thadk...
# 51675  https://www.zomato.com/bangalore/topsy-turvey-...
# 51710  https://www.zomato.com/bangalore/topsy-turvey-...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
#
#                                                  address  \
# 84     161/C, 6th Main, 80 Feet Road, Bhuvaneshwari N...
# 90     BDA Shopping Complex, 24th Cross Road, Siddann...
# 91     Shop 18 , 3rd cross road,Markandeya Layout, Ba...
# ...

# %%
zomato_df['rate']=zomato_df['rate'].str.strip(" NEW/5").replace(["-",''],np.nan)
zomato_df['rate']=zomato_df['rate'].replace(np.nan,0.0)
zomato_df['rate'].unique()
zomato_df['rate']=pd.to_numeric(zomato_df['rate'])

# %%
zomato_df['rate'].unique()
# Out:
# array([4.1, 3.8, 3.7, 3.6, 4.6, 4. , 4.2, 3.9, 3.1, 3. , 3.2, 3.3, 2.8,
#        4.4, 4.3, 0. , 2.9, 2.6, 3.4, 2. , 2.7, 4.7, 2.4, 2.2, 2.3, 4.8,
#        4.9, 2.1, 1.8])

# %%
plt.Figure(figsize=(12,8))
sns.histplot(data=zomato_df[zomato_df['rate']>0],x='rate')
plt.show()

# %%
plt.Figure(figsize=(12,8))
sns.histplot(data=zomato_df[zomato_df['votes']>0],x='votes')
plt.show()

# %%
np.corrcoef(zomato_df['rate'],zomato_df['votes'])
# Out:
# array([[1.        , 0.27630723],
#        [0.27630723, 1.        ]])

# %%
plt.Figure(figsize=(12,8))
sns.scatterplot(data=zomato_df[zomato_df['rate']>0],x='rate',y='votes')
plt.show()

# %%
Missing_Summary=pd.DataFrame({
    'Number Of Nulls':zomato_df.isna().sum(),
    'Nulls Precentage':round((zomato_df.isna().sum()/len(zomato_df))*100,2)
})
Missing_Summary
# Out:
#                              Number Of Nulls  Nulls Precentage
# url                                        0              0.00
# address                                    0              0.00
# name                                       0              0.00
# online_order                               0              0.00
# book_table                                 0              0.00
# rate                                       0              0.00
# votes                                      0              0.00
# phone                                   1208              2.34
# location                                  21              0.04
# rest_type                                227              0.44
# dish_liked                             28078             54.29
# cuisines                                  45              0.09
# approx_cost(for two people)              346              0.67
# reviews_list                               0              0.00
# ...

# %% [markdown]
# # cuisines Column

# %%
cuisines=zomato_df['cuisines']
cuisines
# Out:
# 0                North Indian, Mughlai, Chinese
# 1                   Chinese, North Indian, Thai
# 2                        Cafe, Mexican, Italian
# 3                    South Indian, North Indian
# 4                      North Indian, Rajasthani
#                           ...
# 51712                               Continental
# 51713                               Finger Food
# 51714                               Finger Food
# 51715                               Finger Food
# 51716    Finger Food, North Indian, Continental
# Name: cuisines, Length: 51717, dtype: object

# %%
all_cuisines = zomato_df['cuisines'].dropna().str.split(', ')
flat_list_of_cuisines = [item for sublist in all_cuisines for item in sublist]
unique_cuisines_array = np.unique(flat_list_of_cuisines)
pd.DataFrame(unique_cuisines_array)
# Out:
#               0
# 0        Afghan
# 1       Afghani
# 2       African
# 3      American
# 4        Andhra
# ..          ...
# 102     Tibetan
# 103     Turkish
# 104       Vegan
# 105  Vietnamese
# 106       Wraps
#
# [107 rows x 1 columns]

# %% [markdown]
# # Phone Column

# %%
zomato_df['phone']
# Out:
# 0          080 42297555\r\n+91 9743772233
# 1                            080 41714161
# 2                          +91 9663487993
# 3                          +91 9620009302
# 4        +91 8026612447\r\n+91 9901210005
#                        ...
# 51712                        080 40301477
# 51713                      +91 8197675843
# 51714                                 NaN
# 51715                        080 49652769
# 51716                      +91 8071117272
# Name: phone, Length: 51717, dtype: object

# %% [markdown]
# # Location Column

# %%
zomato_df[['location','votes']].groupby('location').sum().sort_values(by='votes',ascending=False)
# Out:
#                          votes
# location
# Koramangala 5th Block  2219506
# Indiranagar            1196007
# Koramangala 4th Block   685156
# BTM                     619376
# Church Street           594979
# ...                        ...
# KR Puram                   277
# Yelahanka                  189
# Nagarbhavi                  10
# Peenya                       5
# Jakkur                       0
#
# [93 rows x 1 columns]

# %% [markdown]
# # EDA

# %% [markdown]
# # Regression
